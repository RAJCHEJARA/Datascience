# %%
image_data_1={ "Batch_id" : "Batch_for_testing", "image_name" : "cokeandfanta_20.jpg", "isSuccess" : "true", "message" : "success", "records" : [ { "clientSceneData" : { "area" : "Aisle", "poc" : "drinks" }, "sceneUid" : "146s8124-s21g-12d3-a456-223324221542", "facing" : { "brand" : "Fanta", "cname" : " ", "ban" : " ", "category" : "sprkl", "name" : "250MLPLB Fanta Org", "count" : " ", "type" : "sku", "sku" : "21" }, "sceneType" : 1 }, { "clientSceneData" : { "area" : "Aisle", "poc" : "drinks" }, "sceneUid" : "146s8124-s21g-12d3-a456-223324221542", "facing" : { "brand" : "Fanta", "cname" : " ", "ban" : " ", "category" : "sprkl", "name" : "1.75LPLB Fanta Org", "count" : " ", "type" : "nonsku", "sku" : "19" }, "sceneType" : 1 }, { "clientSceneData" : { "area" : "Aisle", "poc" : "drinks" }, "sceneUid" : "146s8124-s21g-12d3-a456-223324221542", "facing" : { "brand" : "Fanta", "cname" : " ", "ban" : " ", "category" : "sprkl", "name" : "200MLGLB Fanta Org", "count" : " ", "type" : "empty", "sku" : "20" }, "sceneType" : 1 }, { "clientSceneData" : { "area" : "Aisle", "poc" : "drinks" }, "sceneUid" : "146s8124-s21g-12d3-a456-223324221542", "facing" : { "brand" : "Kinley", "cname" : " ", "ban" : " ", "category" : "soda", "name" : "1.25MLPLB FANTA org", "count" : " ", "type" : "nonsku", "sku" : "57" }, "sceneType" : 1 }, { "clientSceneData" : { "area" : "Aisle", "poc" : "drinks" }, "sceneUid" : "146s8124-s21g-12d3-a456-223324221542", "facing" : { "brand" : "Fanta", "cname" : " ", "ban" : " ", "category" : "sprkl", "name" : "2.25LPLB Fanta Org", "count" : " ", "type" : "sku", "sku" : "18" }, "sceneType" : 1 }, { "clientSceneData" : { "area" : "Aisle", "poc" : "drinks" }, "sceneUid" : "146s8124-s21g-12d3-a456-223324221542", "facing" : { "brand" : "Sprite", "cname" : " ", "ban" : " ", "category" : "sprkl", "name" : "750MLPLB Fanta Org", "count" : " ", "type" : "sku", "sku" : "17" }, "sceneType" : 1 }, { "clientSceneData" : { "area" : "Aisle", "poc" : "drinks" }, "sceneUid" : "146s8124-s21g-12d3-a456-223324221542", "facing" : { "brand" : "Fanta", "cname" : " ", "ban" : " ", "category" : "sprkl", "name" : "300MLGLB Fanta Org", "count" : " ", "type" : "sku", "sku" : "22" }, "sceneType" : 1 } ] }
image_data_2={ "Batch_id" : "Batch_for_testing", "image_name" : "cokeandfanta_2005.jpg", "isSuccess" : "true", "message" : "success", "records" : [ { "clientSceneData" : { "area" : "Aisle", "poc" : "drinks" }, "sceneUid" : "146s8124-s21g-12d3-a456-223324221542", "facing" : { "brand" : "coolers", "cname" : " ", "ban" : " ", "category" : "", "name" : "coolers", "count" : " ", "type" : "zzzcooler", "sku" : "114" }, "sceneType" : 1 }, { "clientSceneData" : { "area" : "Aisle", "poc" : "drinks" }, "sceneUid" : "146s8124-s21g-12d3-a456-223324221542", "facing" : { "brand" : "Fanta", "cname" : " ", "ban" : " ", "category" : "sprkl", "name" : "1.75LPLB Fanta Org", "count" : " ", "type" : "sku", "sku" : "19" }, "sceneType" : 1 }, { "clientSceneData" : { "area" : "Aisle", "poc" : "drinks" }, "sceneUid" : "146s8124-s21g-12d3-a456-223324221542", "facing" : { "brand" : "Fanta", "cname" : " ", "ban" : " ", "category" : "sprkl", "name" : "200MLGLB Fanta Org", "count" : " ", "type" : "empty", "sku" : "20" }, "sceneType" : 1 }, { "clientSceneData" : { "area" : "Aisle", "poc" : "drinks" }, "sceneUid" : "146s8124-s21g-12d3-a456-223324221542", "facing" : { "brand" : "Kinley", "cname" : " ", "ban" : " ", "category" : "soda", "name" : "1.25MLPLB FANTA org", "count" : " ", "type" : "sku", "sku" : "57" }, "sceneType" : 1 }, { "clientSceneData" : { "area" : "Aisle", "poc" : "drinks" }, "sceneUid" : "146s8124-s21g-12d3-a456-223324221542", "facing" : { "brand" : "Fanta", "cname" : " ", "ban" : " ", "category" : "sprkl", "name" : "2.25LPLB Fanta Org", "count" : " ", "type" : "sku", "sku" : "18" }, "sceneType" : 1 }, { "clientSceneData" : { "area" : "Aisle", "poc" : "drinks" }, "sceneUid" : "146s8124-s21g-12d3-a456-223324221542", "facing" : { "brand" : "Sprite", "cname" : " ", "ban" : " ", "category" : "sprkl", "name" : "750MLPLB Fanta Org", "count" : " ", "type" : "sku", "sku" : "17" }, "sceneType" : 1 }, { "clientSceneData" : { "area" : "Aisle", "poc" : "drinks" }, "sceneUid" : "146s8124-s21g-12d3-a456-223324221542", "facing" : { "brand" : "Bisleri", "cname" : " ", "ban" : " ", "category" : "sprkl", "name" : "water_bottl 250", "count" : " ", "type" : "sku", "sku" : "22" }, "sceneType" : 1 } ] }

#the input data will be dictionary and the output will be except client scene and sceneuid and key as facing
##########function11111111111111##################################
def data_from_mongo_table(dict):
    final_facing_data=[]
    records_data =dict['records']
    for item in records_data:
        item.pop("clientSceneData",None)
        item.pop("sceneUid",None)
        final_facing_data.append(item['facing'])
    return final_facing_data

# here the input is return from the data_from_mongo_table function and output will be munged data
#############function222222222222####################################
import json
import pandas as pd
def facing_proc(data):
    df =pd.DataFrame(data)
    df['Counts'] = df.groupby(['name'])['brand'].transform('count')
    df = df.drop_duplicates()
    df = df.drop(['count'], axis=1)
    return df 

#here the input is dictionary from mongo ,and the above two functions
######function33333333333###########################################
def final_code_for_facing(dict,data_from_mongo_table,facing_proc):
    mongo_data = data_from_mongo_table(dict)
    data_for_facing =facing_proc(mongo_data)
    return data_for_facing

#here we are storing the outputs so that we can pass this output as an input in final_json_facing after appending the two data
data_for_facing_1 =final_code_for_facing(image_data_1,data_from_mongo_table,facing_proc)
data_for_facing_2 =final_code_for_facing(image_data_2,data_from_mongo_table,facing_proc)

#this function is for getting the final output for purity as dictionary
###########function444444444444444444##################################
def final_json_purity(df_1,df_2,purity_data):
    appended_dataframe =df_1.append(df_2)
    new_dataframe = complete_data(appended_dataframe)
    data_to_return =purity_data(new_dataframe)
    return data_to_return

#this function is for getting the list of the facing data
#######################function555555555555555##########################
def final_json_facing(df_1,df_2,complete_data):
    appended_dataframe =df_1.append(df_2)
    new_dataframe =complete_data(appended_dataframe)
    dictionary_format = new_dataframe.to_dict(orient='records')
    dumping_in_string = json.dumps(dictionary_format)
    loading_in_list = json.loads(dumping_in_string)
    return loading_in_list
    


#this function is for getting the correct value what is required in maxexperinece with the counts of each type
######################function666666666666666###################################
def complete_data(appended_dataframe):
    new_dataframe =appended_dataframe.groupby(['cname','type','category','brand','ban','name','sku'],as_index=False)['Counts'].sum()
    return new_dataframe

#this will give you the dictionary for the purity thing
########################function7777777777777777777###############################
def purity_data(consolidated_data):
    dictionary ={}
    processing_data =consolidated_data[['type','Counts']]
    processing_data =processing_data.groupby("type").sum()
    dictionary['totalFacing'] =processing_data['Counts'][1]+processing_data['Counts'][2]
    dictionary["cokeSKUs"] =processing_data['Counts'][2]
    dictionary["nonCokeSKUs"] =processing_data['Counts'][1]
    dictionary["empty"] =processing_data['Counts'][0]
    return dictionary

# %%
from collections import OrderedDict
def final_consolidated_json(dict1,dict2,data_dictionary):
    consolidated_order = {}
    consolidated_order['success'] = "true"
    consolidated_order['data']=data_dictionary(dict1,dict2)
    return consolidated_order

# %%
def data_dictionary(dict1,dict2):
    data = {}
    first_dictionary = final_code_for_facing(dict1,data_from_mongo_table,facing_proc)
    second_dictionary =final_code_for_facing(dict2,data_from_mongo_table,facing_proc)
    purity_data_for = final_json_purity(first_dictionary,second_dictionary,purity_data)
    facing_data =  final_json_facing(first_dictionary,second_dictionary,complete_data)
    data['sceneUid'] = dict1["Batch_id"]
    data['sceneType'] =1
    data['purity'] = purity_data_for
    data['clientSceneData'] = "{'area': 'Aisle', 'poc':'drinks'}"
    data['coolerDoors'] = 2
    data['sceneImages'] = ""
    data['facing'] = facing_data
    return data

# %%
test_1 = {'message': 'success', 'Batch_id': 'Batch_for_testing', 'records': [{'facing': {'ban': ' ', 'category': 'sprkl', 'brand': 'Fanta', 'sku': '21', 'type': 'sku', 'count': ' ', 'name': '250MLPLB Fanta Org', 'cname': ' '}, 'clientSceneData': {'area': 'Aisle', 'poc': 'drinks'}, 'sceneType': 1.0, 'sceneUid': '146s8124-s21g-12d3-a456-223324221542'}, {'facing': {'ban': ' ', 'category': 'sprkl', 'brand': 'Fanta', 'sku': '19', 'type': 'sku', 'count': ' ', 'name': '1.75LPLB Fanta Org', 'cname': ' '}, 'clientSceneData': {'area': 'Aisle', 'poc': 'drinks'}, 'sceneType': 1.0, 'sceneUid': '146s8124-s21g-12d3-a456-223324221542'}, {'facing': {'ban': ' ', 'category': 'sprkl', 'brand': 'Fanta', 'sku': '20', 'type': 'sku', 'count': ' ', 'name': '200MLGLB Fanta Org', 'cname': ' '}, 'clientSceneData': {'area': 'Aisle', 'poc': 'drinks'}, 'sceneType': 1.0, 'sceneUid': '146s8124-s21g-12d3-a456-223324221542'}, {'facing': {'ban': ' ', 'category': 'soda', 'brand': 'Kinley', 'sku': '57', 'type': 'sku', 'count': ' ', 'name': '1.25MLPLB FANTA org', 'cname': ' '}, 'clientSceneData': {'area': 'Aisle', 'poc': 'drinks'}, 'sceneType': 1.0, 'sceneUid': '146s8124-s21g-12d3-a456-223324221542'}, {'facing': {'ban': ' ', 'category': 'sprkl', 'brand': 'Fanta', 'sku': '18', 'type': 'sku', 'count': ' ', 'name': '2.25LPLB Fanta Org', 'cname': ' '}, 'clientSceneData': {'area': 'Aisle', 'poc': 'drinks'}, 'sceneType': 1.0, 'sceneUid': '146s8124-s21g-12d3-a456-223324221542'}, {'facing': {'ban': ' ', 'category': 'sprkl', 'brand': 'Sprite', 'sku': '17', 'type': 'sku', 'count': ' ', 'name': '750MLPLB Fanta Org', 'cname': ' '}, 'clientSceneData': {'area': 'Aisle', 'poc': 'drinks'}, 'sceneType': 1.0, 'sceneUid': '146s8124-s21g-12d3-a456-223324221542'}, {'facing': {'ban': ' ', 'category': 'sprkl', 'brand': 'Fanta', 'sku': '22', 'type': 'sku', 'count': ' ', 'name': '300MLGLB Fanta Org', 'cname': ' '}, 'clientSceneData': {'area': 'Aisle', 'poc': 'drinks'}, 'sceneType': 1.0, 'sceneUid': '146s8124-s21g-12d3-a456-223324221542'}], 'image_name': 'cokeandfanta_20.jpg'}
test_2 = {'message': 'success', 'Batch_id': 'Batch_for_testing', 'records': [{'facing': {'ban': ' ', 'category': 'sprkl', 'brand': 'Fanta', 'sku': '21', 'type': 'sku', 'count': ' ', 'name': '250MLPLB Fanta Org', 'cname': ' '}, 'clientSceneData': {'area': 'Aisle', 'poc': 'drinks'}, 'sceneType': 1.0, 'sceneUid': '146s8124-s21g-12d3-a456-223324221542'}, {'facing': {'ban': ' ', 'category': 'sprkl', 'brand': 'Fanta', 'sku': '19', 'type': 'sku', 'count': ' ', 'name': '1.75LPLB Fanta Org', 'cname': ' '}, 'clientSceneData': {'area': 'Aisle', 'poc': 'drinks'}, 'sceneType': 1.0, 'sceneUid': '146s8124-s21g-12d3-a456-223324221542'}, {'facing': {'ban': ' ', 'category': 'sprkl', 'brand': 'Fanta', 'sku': '20', 'type': 'sku', 'count': ' ', 'name': '200MLGLB Fanta Org', 'cname': ' '}, 'clientSceneData': {'area': 'Aisle', 'poc': 'drinks'}, 'sceneType': 1.0, 'sceneUid': '146s8124-s21g-12d3-a456-223324221542'}, {'facing': {'ban': ' ', 'category': 'soda', 'brand': 'Kinley', 'sku': '57', 'type': 'sku', 'count': ' ', 'name': '1.25MLPLB FANTA org', 'cname': ' '}, 'clientSceneData': {'area': 'Aisle', 'poc': 'drinks'}, 'sceneType': 1.0, 'sceneUid': '146s8124-s21g-12d3-a456-223324221542'}, {'facing': {'ban': ' ', 'category': 'sprkl', 'brand': 'Fanta', 'sku': '18', 'type': 'sku', 'count': ' ', 'name': '2.25LPLB Fanta Org', 'cname': ' '}, 'clientSceneData': {'area': 'Aisle', 'poc': 'drinks'}, 'sceneType': 1.0, 'sceneUid': '146s8124-s21g-12d3-a456-223324221542'}, {'facing': {'ban': ' ', 'category': 'sprkl', 'brand': 'Sprite', 'sku': '17', 'type': 'sku', 'count': ' ', 'name': '750MLPLB Fanta Org', 'cname': ' '}, 'clientSceneData': {'area': 'Aisle', 'poc': 'drinks'}, 'sceneType': 1.0, 'sceneUid': '146s8124-s21g-12d3-a456-223324221542'}, {'facing': {'ban': ' ', 'category': 'sprkl', 'brand': 'Fanta', 'sku': '22', 'type': 'sku', 'count': ' ', 'name': '300MLGLB Fanta Org', 'cname': ' '}, 'clientSceneData': {'area': 'Aisle', 'poc': 'drinks'}, 'sceneType': 1.0, 'sceneUid': '146s8124-s21g-12d3-a456-223324221542'}], 'image_name': 'cokeandfanta_2005.jpg'}

# %%
data_for_mong_1 = data_from_mongo_table(test_1)
data_for_mong_2 = data_from_mongo_table(test_2)

# %%
facing_data_1 = facing_proc(data_for_mong_1)
facing_data_2 = facing_proc(data_for_mong_2)

# %%
appended_dataframe =facing_data_1.append(facing_data_2)

# %%
complete_data_for =complete_data(appended_dataframe)

# %%
complete_data_for
# Out:
#   cname type category   brand ban                 name sku  Counts
# 0        sku     soda  Kinley      1.25MLPLB FANTA org  57       2
# 1        sku    sprkl   Fanta       1.75LPLB Fanta Org  19       2
# 2        sku    sprkl   Fanta       2.25LPLB Fanta Org  18       2
# 3        sku    sprkl   Fanta       200MLGLB Fanta Org  20       2
# 4        sku    sprkl   Fanta       250MLPLB Fanta Org  21       2
# 5        sku    sprkl   Fanta       300MLGLB Fanta Org  22       2
# 6        sku    sprkl  Sprite       750MLPLB Fanta Org  17       2

# %%
dictionary_format = complete_data_for.to_dict(orient='records')
dumping_in_string = json.dumps(dictionary_format)
loading_in_list = json.loads(dumping_in_string)

# %%
first_dictionary = final_code_for_facing(test_1,data_from_mongo_table,facing_proc)
second_dictionary =final_code_for_facing(test_2,data_from_mongo_table,facing_proc)
purity_data_for = final_json_purity(first_dictionary,second_dictionary,purity_data)
facing_data =  final_json_facing(first_dictionary,second_dictionary,complete_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# ...
