# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import xgboost as xgb
import operator
import sklearn
import matplotlib
matplotlib.use("Agg") #Needed to save figures
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
# %matplotlib inline

# %%
# Gather some features
def build_features(features, data):
    # remove NaNs
    data.fillna(0, inplace=True)
    data.loc[data.Open.isnull(), 'Open'] = 1
    # Use some properties directly
    features.extend(['Store', 'CompetitionDistance', 'Promo', 'Promo2', 'SchoolHoliday'])

    # Label encode some features
    features.extend(['StoreType', 'Assortment', 'StateHoliday'])
    mappings = {'0':0, 'a':1, 'b':2, 'c':3, 'd':4}
    data.StoreType.replace(mappings, inplace=True)
    data.Assortment.replace(mappings, inplace=True)
    data.StateHoliday.replace(mappings, inplace=True)

    features.extend(['DayOfWeek', 'Month', 'Day', 'Year', 'WeekOfYear'])
    data['Year'] = data.Date.dt.year
    data['Month'] = data.Date.dt.month
    data['Day'] = data.Date.dt.day
    data['DayOfWeek'] = data.Date.dt.dayofweek
    data['WeekOfYear'] = data.Date.dt.weekofyear
    # Calculate time competition open time in months
    features.append('CompetitionOpen')
    data['CompetitionOpen'] = 12 * (data.Year - data.CompetitionOpenSinceYear) + \
        (data.Month - data.CompetitionOpenSinceMonth)
    # Promo open time in months
    features.append('PromoOpen')
    data['PromoOpen'] = 12 * (data.Year - data.Promo2SinceYear) + \
        (data.WeekOfYear - data.Promo2SinceWeek) / 4.0
    data['PromoOpen'] = data.PromoOpen.apply(lambda x: x if x > 0 else 0)
    data.loc[data.Promo2SinceYear == 0, 'PromoOpen'] = 0
    # Indicate that sales on that day are in promo interval
    features.append('IsPromoMonth')
    month2str = {1:'Jan', 2:'Feb', 3:'Mar', 4:'Apr', 5:'May', 6:'Jun', \
             7:'Jul', 8:'Aug', 9:'Sept', 10:'Oct', 11:'Nov', 12:'Dec'}
    data['monthStr'] = data.Month.map(month2str)
    data.loc[data.PromoInterval == 0, 'PromoInterval'] = ''
    data['IsPromoMonth'] = 0
    for interval in data.PromoInterval.unique():
        if interval != '':
            for month in interval.split(','):
                data.loc[(data.monthStr == month) & (data.PromoInterval == interval), 'IsPromoMonth'] = 1

    return data

# %%
print("Load the training, test and store data using pandas")
types = {'CompetitionOpenSinceYear': np.dtype(int),
         'CompetitionOpenSinceMonth': np.dtype(int),
         'StateHoliday': np.dtype(str),
         'Promo2SinceWeek': np.dtype(int),
         'SchoolHoliday': np.dtype(float),
         'PromoInterval': np.dtype(str)}
train = pd.read_csv("C:/Forcasting/XGBOOST/train.csv", parse_dates=[2], dtype=types)
test = pd.read_csv("C:/Forcasting/XGBOOST/test.csv", parse_dates=[3], dtype=types)
store = pd.read_csv("C:/Forcasting/XGBOOST/store.csv")
# Out:
# Load the training, test and store data using pandas

# %%
train
# Out:
#         Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0           1          4 2015-07-31   5263        555     1      1
# 1           1          3 2015-07-30   5020        546     1      1
# 2           1          2 2015-07-29   4782        523     1      1
# 3           1          1 2015-07-28   5011        560     1      1
# 4           1          0 2015-07-27   6102        612     1      1
# ...       ...        ...        ...    ...        ...   ...    ...
# 844333    292          0 2013-01-07   9291       1002     1      1
# 844334    292          5 2013-01-05   2748        340     1      0
# 844335    292          4 2013-01-04   4202        560     1      0
# 844336    292          3 2013-01-03   4580        662     1      0
# 844337    292          2 2013-01-02   5076        672     1      0
#
#         StateHoliday  SchoolHoliday  StoreType  ...  Promo2SinceYear  \
# 0                  0            1.0          3  ...              0.0
# 1                  0            1.0          3  ...              0.0
# 2                  0            1.0          3  ...              0.0
# 3                  0            1.0          3  ...              0.0
# 4                  0            1.0          3  ...              0.0
# ...              ...            ...        ...  ...              ...
# 844333             0            0.0          1  ...              0.0
# 844334             0            0.0          1  ...              0.0
# 844335             0            1.0          1  ...              0.0
# 844336             0            1.0          1  ...              0.0
# 844337             0            1.0          1  ...              0.0
#
#         PromoInterval  Year  Month  Day  WeekOfYear  CompetitionOpen  \
# 0                      2015      7   31          31             82.0
# 1                      2015      7   30          31             82.0
# 2                      2015      7   29          31             82.0
# 3                      2015      7   28          31             82.0
# 4                      2015      7   27          31             82.0
# ...               ...   ...    ...  ...         ...              ...
# 844333                 2013      1    7           2             43.0
# 844334                 2013      1    5           1             43.0
# 844335                 2013      1    4           1             43.0
# 844336                 2013      1    3           1             43.0
# 844337                 2013      1    2           1             43.0
#
#        PromoOpen  monthStr  IsPromoMonth
# 0            0.0       Jul             0
# 1            0.0       Jul             0
# 2            0.0       Jul             0
# 3            0.0       Jul             0
# 4            0.0       Jul             0
# ...          ...       ...           ...
# 844333       0.0       Jan             0
# 844334       0.0       Jan             0
# 844335       0.0       Jan             0
# 844336       0.0       Jan             0
# 844337       0.0       Jan             0
#
# [844338 rows x 26 columns]

# %%
print("Assume store open, if not provided")
train.fillna(1, inplace=True)
test.fillna(1, inplace=True)

print("Consider only open stores for training. Closed stores wont count into the score.")
train = train[train["Open"] != 0]
print("Use only Sales bigger then zero. Simplifies calculation of rmspe")
train = train[train["Sales"] > 0]

print("Join with store")
train = pd.merge(train, store, on='Store')
test = pd.merge(test, store, on='Store')
# Out:
# Assume store open, if not provided
# Consider only open stores for training. Closed stores wont count into the score.
# Use only Sales bigger then zero. Simplifies calculation of rmspe
# Join with store

# %%
features = []

print("augment features")
build_features(features, train)
build_features([], test)
print(features)

print('training data processed')
# Out:
# augment features
# ['Store', 'CompetitionDistance', 'Promo', 'Promo2', 'SchoolHoliday', 'StoreType', 'Assortment', 'StateHoliday', 'DayOfWeek', 'Month', 'Day', 'Year', 'WeekOfYear', 'CompetitionOpen', 'PromoOpen', 'IsPromoMonth']
# training data processed

# %%
def rmspe(y, yhat):
    return np.sqrt(np.mean((yhat/y-1) ** 2))

def rmspe_xg(yhat, y):
    y = np.expm1(y.get_label())
    yhat = np.expm1(yhat)
    return "rmspe", rmspe(y,yhat)

# %%
train[features]
# Out:
#         Store  CompetitionDistance  Promo  Promo2  SchoolHoliday  StoreType  \
# 0           1               1270.0      1       0            1.0          3
# 1           1               1270.0      1       0            1.0          3
# 2           1               1270.0      1       0            1.0          3
# 3           1               1270.0      1       0            1.0          3
# 4           1               1270.0      1       0            1.0          3
# ...       ...                  ...    ...     ...            ...        ...
# 844333    292               1100.0      1       0            0.0          1
# 844334    292               1100.0      0       0            0.0          1
# 844335    292               1100.0      0       0            1.0          1
# 844336    292               1100.0      0       0            1.0          1
# 844337    292               1100.0      0       0            1.0          1
#
#         Assortment  StateHoliday  DayOfWeek  Month  Day  Year  WeekOfYear  \
# 0                1             0          4      7   31  2015          31
# 1                1             0          3      7   30  2015          31
# 2                1             0          2      7   29  2015          31
# 3                1             0          1      7   28  2015          31
# 4                1             0          0      7   27  2015          31
# ...            ...           ...        ...    ...  ...   ...         ...
# 844333           1             0          0      1    7  2013           2
# 844334           1             0          5      1    5  2013           1
# 844335           1             0          4      1    4  2013           1
# 844336           1             0          3      1    3  2013           1
# 844337           1             0          2      1    2  2013           1
#
#         CompetitionOpen  PromoOpen  IsPromoMonth
# 0                  82.0        0.0             0
# 1                  82.0        0.0             0
# 2                  82.0        0.0             0
# 3                  82.0        0.0             0
# 4                  82.0        0.0             0
# ...                 ...        ...           ...
# 844333             43.0        0.0             0
# 844334             43.0        0.0             0
# 844335             43.0        0.0             0
# 844336             43.0        0.0             0
# 844337             43.0        0.0             0
#
# [844338 rows x 16 columns]

# %%
new_feature =['Store', 'CompetitionDistance', 'Promo', 'Promo2', 'SchoolHoliday', 'StoreType', 'Assortment', 'StateHoliday', 'DayOfWeek', 'Month', 'Day', 'Year', 'WeekOfYear', 'CompetitionOpen', 'PromoOpen', 'IsPromoMonth','Sales',"Date"]

# %%
train[new_feature]
# Out:
#         Store  CompetitionDistance  Promo  Promo2  SchoolHoliday  StoreType  \
# 0           1               1270.0      1       0            1.0          3
# 1           1               1270.0      1       0            1.0          3
# 2           1               1270.0      1       0            1.0          3
# 3           1               1270.0      1       0            1.0          3
# 4           1               1270.0      1       0            1.0          3
# ...       ...                  ...    ...     ...            ...        ...
# 844333    292               1100.0      1       0            0.0          1
# 844334    292               1100.0      0       0            0.0          1
# 844335    292               1100.0      0       0            1.0          1
# 844336    292               1100.0      0       0            1.0          1
# 844337    292               1100.0      0       0            1.0          1
#
#         Assortment  StateHoliday  DayOfWeek  Month  Day  Year  WeekOfYear  \
# 0                1             0          4      7   31  2015          31
# 1                1             0          3      7   30  2015          31
# 2                1             0          2      7   29  2015          31
# 3                1             0          1      7   28  2015          31
# 4                1             0          0      7   27  2015          31
# ...            ...           ...        ...    ...  ...   ...         ...
# 844333           1             0          0      1    7  2013           2
# 844334           1             0          5      1    5  2013           1
# 844335           1             0          4      1    4  2013           1
# 844336           1             0          3      1    3  2013           1
# 844337           1             0          2      1    2  2013           1
#
#         CompetitionOpen  PromoOpen  IsPromoMonth  Sales       Date
# 0                  82.0        0.0             0   5263 2015-07-31
# 1                  82.0        0.0             0   5020 2015-07-30
# 2                  82.0        0.0             0   4782 2015-07-29
# 3                  82.0        0.0             0   5011 2015-07-28
# 4                  82.0        0.0             0   6102 2015-07-27
# ...                 ...        ...           ...    ...        ...
# 844333             43.0        0.0             0   9291 2013-01-07
# 844334             43.0        0.0             0   2748 2013-01-05
# 844335             43.0        0.0             0   4202 2013-01-04
# 844336             43.0        0.0             0   4580 2013-01-03
# 844337             43.0        0.0             0   5076 2013-01-02
#
# [844338 rows x 18 columns]

# %%
train[new_feature].to_csv("final_features_for.csv")

# %%
params = {"objective": "reg:linear",
          "booster" : "gbtree",
          "eta": 0.3,
          "max_depth": 10,
          "subsample": 0.9,
          "colsample_bytree": 0.7,
          "silent": 1,
          "seed": 1301
          }
num_boost_round = 300

print("Train a XGBoost model")
X_train, X_valid = train_test_split(train, test_size=0.012, random_state=10)
y_train = np.log1p(X_train.Sales)
y_valid = np.log1p(X_valid.Sales)
dtrain = xgb.DMatrix(X_train[features], y_train)
dvalid = xgb.DMatrix(X_valid[features], y_valid)

watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
gbm = xgb.train(params, dtrain, num_boost_round, evals=watchlist, \
early_stopping_rounds=100, feval=rmspe_xg, verbose_eval=True)
# Out:
# Train a XGBoost model
# [15:00:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.1.0/src/objective/regression_obj.cu:168: reg:linear is now deprecated in favor of reg:squarederror.
# [15:00:17] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	train-rmse:5.79445	eval-rmse:5.79367	train-rmspe:0.99683	eval-rmspe:0.99682
# Multiple eval metrics have been passed: 'eval-rmspe' will be used for early stopping.
#
# Will train until eval-rmspe hasn't improved in 100 rounds.
# [1]	train-rmse:4.06392	eval-rmse:4.06338	train-rmspe:0.98147	eval-rmspe:0.98144
# [2]	train-rmse:2.85304	eval-rmse:2.85290	train-rmspe:0.93818	eval-rmspe:0.93810
# [3]	train-rmse:2.00947	eval-rmse:2.00981	train-rmspe:0.85676	eval-rmspe:0.85652
# [4]	train-rmse:1.42327	eval-rmse:1.42395	train-rmspe:0.74394	eval-rmspe:0.74311
# [5]	train-rmse:1.01735	eval-rmse:1.01835	train-rmspe:0.61942	eval-rmspe:0.61711
# [6]	train-rmse:0.74050	eval-rmse:0.74180	train-rmspe:0.50418	eval-rmspe:0.49884
# [7]	train-rmse:0.55583	eval-rmse:0.55736	train-rmspe:0.41270	eval-rmspe:0.40286
# [8]	train-rmse:0.42978	eval-rmse:0.43107	train-rmspe:0.34790	eval-rmspe:0.33257
# [9]	train-rmse:0.35031	eval-rmse:0.35183	train-rmspe:0.30950	eval-rmspe:0.28851
# [10]	train-rmse:0.30449	eval-rmse:0.30613	train-rmspe:0.29223	eval-rmspe:0.26686
# [11]	train-rmse:0.27789	eval-rmse:0.27983	train-rmspe:0.28610	eval-rmspe:0.25821
# [12]	train-rmse:0.25832	eval-rmse:0.25984	train-rmspe:0.28075	eval-rmspe:0.24991
# [13]	train-rmse:0.24600	eval-rmse:0.24727	train-rmspe:0.27112	eval-rmspe:0.24572
# [14]	train-rmse:0.23739	eval-rmse:0.23804	train-rmspe:0.26911	eval-rmspe:0.24156
# [15]	train-rmse:0.21713	eval-rmse:0.21806	train-rmspe:0.25352	eval-rmspe:0.22442
# [16]	train-rmse:0.21333	eval-rmse:0.21434	train-rmspe:0.25281	eval-rmspe:0.22312
# [17]	train-rmse:0.20702	eval-rmse:0.20825	train-rmspe:0.24672	eval-rmspe:0.21743
# [18]	train-rmse:0.20259	eval-rmse:0.20392	train-rmspe:0.24365	eval-rmspe:0.21437
# [19]	train-rmse:0.19371	eval-rmse:0.19475	train-rmspe:0.23613	eval-rmspe:0.20520
# [20]	train-rmse:0.18744	eval-rmse:0.18869	train-rmspe:0.23034	eval-rmspe:0.19928
# [21]	train-rmse:0.17710	eval-rmse:0.17818	train-rmspe:0.21979	eval-rmspe:0.18847
# [22]	train-rmse:0.17316	eval-rmse:0.17431	train-rmspe:0.21515	eval-rmspe:0.18464
# [23]	train-rmse:0.17076	eval-rmse:0.17172	train-rmspe:0.21316	eval-rmspe:0.18205
# [24]	train-rmse:0.16813	eval-rmse:0.16896	train-rmspe:0.21086	eval-rmspe:0.17907
# [25]	train-rmse:0.16729	eval-rmse:0.16810	train-rmspe:0.20799	eval-rmspe:0.17826
# [26]	train-rmse:0.16550	eval-rmse:0.16609	train-rmspe:0.20628	eval-rmspe:0.17620
# [27]	train-rmse:0.16302	eval-rmse:0.16396	train-rmspe:0.20396	eval-rmspe:0.17396
# [28]	train-rmse:0.15946	eval-rmse:0.16032	train-rmspe:0.20052	eval-rmspe:0.16994
# [29]	train-rmse:0.15858	eval-rmse:0.15954	train-rmspe:0.19906	eval-rmspe:0.16917
# [30]	train-rmse:0.15656	eval-rmse:0.15776	train-rmspe:0.19620	eval-rmspe:0.16709
# [31]	train-rmse:0.15444	eval-rmse:0.15566	train-rmspe:0.19400	eval-rmspe:0.16461
# [32]	train-rmse:0.15365	eval-rmse:0.15505	train-rmspe:0.19332	eval-rmspe:0.16401
# [33]	train-rmse:0.15139	eval-rmse:0.15295	train-rmspe:0.19112	eval-rmspe:0.16173
# [34]	train-rmse:0.14963	eval-rmse:0.15115	train-rmspe:0.18941	eval-rmspe:0.15995
# [35]	train-rmse:0.14848	eval-rmse:0.15007	train-rmspe:0.18796	eval-rmspe:0.15870
# [36]	train-rmse:0.14707	eval-rmse:0.14878	train-rmspe:0.16924	eval-rmspe:0.15734
# [37]	train-rmse:0.14683	eval-rmse:0.14853	train-rmspe:0.16897	eval-rmspe:0.15705
# [38]	train-rmse:0.14543	eval-rmse:0.14722	train-rmspe:0.16744	eval-rmspe:0.15558
# [39]	train-rmse:0.14365	eval-rmse:0.14563	train-rmspe:0.16194	eval-rmspe:0.15388
# [40]	train-rmse:0.14080	eval-rmse:0.14298	train-rmspe:0.15900	eval-rmspe:0.15094
# [41]	train-rmse:0.13885	eval-rmse:0.14120	train-rmspe:0.15706	eval-rmspe:0.14901
# [42]	train-rmse:0.13770	eval-rmse:0.14014	train-rmspe:0.15590	eval-rmspe:0.14778
# [43]	train-rmse:0.13633	eval-rmse:0.13878	train-rmspe:0.15462	eval-rmspe:0.14656
# [44]	train-rmse:0.13508	eval-rmse:0.13758	train-rmspe:0.15335	eval-rmspe:0.14527
# [45]	train-rmse:0.13457	eval-rmse:0.13701	train-rmspe:0.15282	eval-rmspe:0.14475
# [46]	train-rmse:0.13256	eval-rmse:0.13491	train-rmspe:0.15079	eval-rmspe:0.14244
# [47]	train-rmse:0.13067	eval-rmse:0.13285	train-rmspe:0.14878	eval-rmspe:0.14003
# [48]	train-rmse:0.12948	eval-rmse:0.13187	train-rmspe:0.14648	eval-rmspe:0.13902
# [49]	train-rmse:0.12853	eval-rmse:0.13103	train-rmspe:0.14556	eval-rmspe:0.13824
# [50]	train-rmse:0.12755	eval-rmse:0.13008	train-rmspe:0.14457	eval-rmspe:0.13706
# [51]	train-rmse:0.12517	eval-rmse:0.12739	train-rmspe:0.14225	eval-rmspe:0.13425
# [52]	train-rmse:0.12487	eval-rmse:0.12713	train-rmspe:0.14195	eval-rmspe:0.13395
# [53]	train-rmse:0.12359	eval-rmse:0.12584	train-rmspe:0.14073	eval-rmspe:0.13270
# [54]	train-rmse:0.12287	eval-rmse:0.12530	train-rmspe:0.13944	eval-rmspe:0.13220
# [55]	train-rmse:0.12175	eval-rmse:0.12436	train-rmspe:0.13820	eval-rmspe:0.13117
# [56]	train-rmse:0.11987	eval-rmse:0.12269	train-rmspe:0.13635	eval-rmspe:0.12946
# [57]	train-rmse:0.11934	eval-rmse:0.12217	train-rmspe:0.13586	eval-rmspe:0.12887
# [58]	train-rmse:0.11901	eval-rmse:0.12195	train-rmspe:0.13551	eval-rmspe:0.12863
# [59]	train-rmse:0.11879	eval-rmse:0.12177	train-rmspe:0.13531	eval-rmspe:0.12849
# [60]	train-rmse:0.11817	eval-rmse:0.12119	train-rmspe:0.13460	eval-rmspe:0.12781
# [61]	train-rmse:0.11738	eval-rmse:0.12037	train-rmspe:0.13380	eval-rmspe:0.12694
# [62]	train-rmse:0.11705	eval-rmse:0.12004	train-rmspe:0.13327	eval-rmspe:0.12657
# [63]	train-rmse:0.11614	eval-rmse:0.11924	train-rmspe:0.13236	eval-rmspe:0.12578
# [64]	train-rmse:0.11550	eval-rmse:0.11877	train-rmspe:0.13163	eval-rmspe:0.12532
# [65]	train-rmse:0.11467	eval-rmse:0.11799	train-rmspe:0.13082	eval-rmspe:0.12447
# [66]	train-rmse:0.11340	eval-rmse:0.11683	train-rmspe:0.12951	eval-rmspe:0.12299
# [67]	train-rmse:0.11316	eval-rmse:0.11665	train-rmspe:0.12944	eval-rmspe:0.12283
# [68]	train-rmse:0.11306	eval-rmse:0.11652	train-rmspe:0.12938	eval-rmspe:0.12266
# [69]	train-rmse:0.11270	eval-rmse:0.11622	train-rmspe:0.12901	eval-rmspe:0.12237
# [70]	train-rmse:0.11235	eval-rmse:0.11597	train-rmspe:0.12866	eval-rmspe:0.12211
# [71]	train-rmse:0.11187	eval-rmse:0.11553	train-rmspe:0.12804	eval-rmspe:0.12157
# [72]	train-rmse:0.11127	eval-rmse:0.11495	train-rmspe:0.12674	eval-rmspe:0.12096
# [73]	train-rmse:0.11073	eval-rmse:0.11456	train-rmspe:0.12623	eval-rmspe:0.12062
# [74]	train-rmse:0.11010	eval-rmse:0.11400	train-rmspe:0.12561	eval-rmspe:0.12005
# [75]	train-rmse:0.10952	eval-rmse:0.11357	train-rmspe:0.12500	eval-rmspe:0.11958
# [76]	train-rmse:0.10940	eval-rmse:0.11349	train-rmspe:0.12489	eval-rmspe:0.11950
# [77]	train-rmse:0.10901	eval-rmse:0.11319	train-rmspe:0.12446	eval-rmspe:0.11917
# [78]	train-rmse:0.10842	eval-rmse:0.11262	train-rmspe:0.12389	eval-rmspe:0.11855
# [79]	train-rmse:0.10797	eval-rmse:0.11226	train-rmspe:0.12339	eval-rmspe:0.11817
# [80]	train-rmse:0.10765	eval-rmse:0.11196	train-rmspe:0.12310	eval-rmspe:0.11785
# [81]	train-rmse:0.10717	eval-rmse:0.11157	train-rmspe:0.12260	eval-rmspe:0.11743
# [82]	train-rmse:0.10670	eval-rmse:0.11106	train-rmspe:0.12209	eval-rmspe:0.11682
# [83]	train-rmse:0.10652	eval-rmse:0.11097	train-rmspe:0.12191	eval-rmspe:0.11675
# [84]	train-rmse:0.10611	eval-rmse:0.11071	train-rmspe:0.12149	eval-rmspe:0.11649
# [85]	train-rmse:0.10599	eval-rmse:0.11061	train-rmspe:0.12137	eval-rmspe:0.11636
# [86]	train-rmse:0.10559	eval-rmse:0.11037	train-rmspe:0.12085	eval-rmspe:0.11604
# [87]	train-rmse:0.10548	eval-rmse:0.11026	train-rmspe:0.12076	eval-rmspe:0.11592
# [88]	train-rmse:0.10505	eval-rmse:0.11003	train-rmspe:0.12014	eval-rmspe:0.11562
# [89]	train-rmse:0.10467	eval-rmse:0.10963	train-rmspe:0.11978	eval-rmspe:0.11517
# [90]	train-rmse:0.10407	eval-rmse:0.10920	train-rmspe:0.11910	eval-rmspe:0.11471
# [91]	train-rmse:0.10375	eval-rmse:0.10890	train-rmspe:0.11877	eval-rmspe:0.11443
# [92]	train-rmse:0.10311	eval-rmse:0.10848	train-rmspe:0.11811	eval-rmspe:0.11400
# [93]	train-rmse:0.10290	eval-rmse:0.10831	train-rmspe:0.11791	eval-rmspe:0.11384
# [94]	train-rmse:0.10246	eval-rmse:0.10794	train-rmspe:0.11743	eval-rmspe:0.11348
# [95]	train-rmse:0.10230	eval-rmse:0.10780	train-rmspe:0.11729	eval-rmspe:0.11336
# [96]	train-rmse:0.10196	eval-rmse:0.10759	train-rmspe:0.11596	eval-rmspe:0.11312
# [97]	train-rmse:0.10172	eval-rmse:0.10736	train-rmspe:0.11569	eval-rmspe:0.11288
# [98]	train-rmse:0.10138	eval-rmse:0.10716	train-rmspe:0.11519	eval-rmspe:0.11269
# [99]	train-rmse:0.10108	eval-rmse:0.10696	train-rmspe:0.11480	eval-rmspe:0.11249
# [100]	train-rmse:0.10080	eval-rmse:0.10684	train-rmspe:0.11452	eval-rmspe:0.11238
# [101]	train-rmse:0.10043	eval-rmse:0.10652	train-rmspe:0.11414	eval-rmspe:0.11205
# [102]	train-rmse:0.10007	eval-rmse:0.10628	train-rmspe:0.11374	eval-rmspe:0.11178
# [103]	train-rmse:0.09983	eval-rmse:0.10617	train-rmspe:0.11345	eval-rmspe:0.11164
# [104]	train-rmse:0.09966	eval-rmse:0.10608	train-rmspe:0.11330	eval-rmspe:0.11158
# [105]	train-rmse:0.09943	eval-rmse:0.10588	train-rmspe:0.11306	eval-rmspe:0.11135
# [106]	train-rmse:0.09921	eval-rmse:0.10568	train-rmspe:0.11285	eval-rmspe:0.11108
# [107]	train-rmse:0.09902	eval-rmse:0.10558	train-rmspe:0.11255	eval-rmspe:0.11098
# [108]	train-rmse:0.09881	eval-rmse:0.10546	train-rmspe:0.11231	eval-rmspe:0.11083
# [109]	train-rmse:0.09872	eval-rmse:0.10540	train-rmspe:0.11222	eval-rmspe:0.11075
# [110]	train-rmse:0.09851	eval-rmse:0.10528	train-rmspe:0.11189	eval-rmspe:0.11060
# [111]	train-rmse:0.09831	eval-rmse:0.10522	train-rmspe:0.11167	eval-rmspe:0.11052
# [112]	train-rmse:0.09783	eval-rmse:0.10471	train-rmspe:0.11111	eval-rmspe:0.10993
# [113]	train-rmse:0.09764	eval-rmse:0.10456	train-rmspe:0.11092	eval-rmspe:0.10978
# [114]	train-rmse:0.09745	eval-rmse:0.10445	train-rmspe:0.11070	eval-rmspe:0.10965
# [115]	train-rmse:0.09692	eval-rmse:0.10397	train-rmspe:0.11003	eval-rmspe:0.10909
# [116]	train-rmse:0.09680	eval-rmse:0.10389	train-rmspe:0.10992	eval-rmspe:0.10899
# [117]	train-rmse:0.09656	eval-rmse:0.10376	train-rmspe:0.10964	eval-rmspe:0.10886
# [118]	train-rmse:0.09632	eval-rmse:0.10366	train-rmspe:0.10941	eval-rmspe:0.10874
# [119]	train-rmse:0.09602	eval-rmse:0.10342	train-rmspe:0.10911	eval-rmspe:0.10850
# [120]	train-rmse:0.09566	eval-rmse:0.10318	train-rmspe:0.10869	eval-rmspe:0.10822
# [121]	train-rmse:0.09541	eval-rmse:0.10304	train-rmspe:0.10824	eval-rmspe:0.10794
# [122]	train-rmse:0.09515	eval-rmse:0.10274	train-rmspe:0.10795	eval-rmspe:0.10762
# [123]	train-rmse:0.09487	eval-rmse:0.10249	train-rmspe:0.10767	eval-rmspe:0.10737
# [124]	train-rmse:0.09471	eval-rmse:0.10238	train-rmspe:0.10749	eval-rmspe:0.10724
# [125]	train-rmse:0.09443	eval-rmse:0.10216	train-rmspe:0.10701	eval-rmspe:0.10702
# [126]	train-rmse:0.09432	eval-rmse:0.10204	train-rmspe:0.10691	eval-rmspe:0.10690
# [127]	train-rmse:0.09418	eval-rmse:0.10195	train-rmspe:0.10675	eval-rmspe:0.10680
# [128]	train-rmse:0.09406	eval-rmse:0.10188	train-rmspe:0.10658	eval-rmspe:0.10674
# [129]	train-rmse:0.09387	eval-rmse:0.10174	train-rmspe:0.10557	eval-rmspe:0.10660
# [130]	train-rmse:0.09369	eval-rmse:0.10169	train-rmspe:0.10536	eval-rmspe:0.10656
# [131]	train-rmse:0.09345	eval-rmse:0.10149	train-rmspe:0.10510	eval-rmspe:0.10635
# [132]	train-rmse:0.09328	eval-rmse:0.10135	train-rmspe:0.10494	eval-rmspe:0.10621
# [133]	train-rmse:0.09315	eval-rmse:0.10129	train-rmspe:0.10481	eval-rmspe:0.10613
# [134]	train-rmse:0.09294	eval-rmse:0.10103	train-rmspe:0.10448	eval-rmspe:0.10571
# [135]	train-rmse:0.09279	eval-rmse:0.10093	train-rmspe:0.10432	eval-rmspe:0.10562
# [136]	train-rmse:0.09274	eval-rmse:0.10091	train-rmspe:0.10413	eval-rmspe:0.10561
# [137]	train-rmse:0.09263	eval-rmse:0.10082	train-rmspe:0.10400	eval-rmspe:0.10552
# [138]	train-rmse:0.09244	eval-rmse:0.10074	train-rmspe:0.10368	eval-rmspe:0.10544
# [139]	train-rmse:0.09229	eval-rmse:0.10066	train-rmspe:0.10353	eval-rmspe:0.10536
# [140]	train-rmse:0.09223	eval-rmse:0.10062	train-rmspe:0.10347	eval-rmspe:0.10530
# [141]	train-rmse:0.09201	eval-rmse:0.10043	train-rmspe:0.10327	eval-rmspe:0.10510
# [142]	train-rmse:0.09191	eval-rmse:0.10037	train-rmspe:0.10299	eval-rmspe:0.10502
# [143]	train-rmse:0.09176	eval-rmse:0.10029	train-rmspe:0.10282	eval-rmspe:0.10495
# [144]	train-rmse:0.09172	eval-rmse:0.10025	train-rmspe:0.10273	eval-rmspe:0.10490
# [145]	train-rmse:0.09156	eval-rmse:0.10016	train-rmspe:0.10256	eval-rmspe:0.10478
# [146]	train-rmse:0.09130	eval-rmse:0.09993	train-rmspe:0.10227	eval-rmspe:0.10455
# [147]	train-rmse:0.09095	eval-rmse:0.09970	train-rmspe:0.10190	eval-rmspe:0.10429
# [148]	train-rmse:0.09081	eval-rmse:0.09957	train-rmspe:0.10175	eval-rmspe:0.10416
# [149]	train-rmse:0.09063	eval-rmse:0.09951	train-rmspe:0.10157	eval-rmspe:0.10408
# [150]	train-rmse:0.09055	eval-rmse:0.09950	train-rmspe:0.10149	eval-rmspe:0.10409
# [151]	train-rmse:0.09038	eval-rmse:0.09936	train-rmspe:0.10130	eval-rmspe:0.10395
# [152]	train-rmse:0.09025	eval-rmse:0.09928	train-rmspe:0.10115	eval-rmspe:0.10389
# [153]	train-rmse:0.09004	eval-rmse:0.09917	train-rmspe:0.10085	eval-rmspe:0.10373
# [154]	train-rmse:0.08986	eval-rmse:0.09910	train-rmspe:0.10064	eval-rmspe:0.10367
# [155]	train-rmse:0.08955	eval-rmse:0.09891	train-rmspe:0.10029	eval-rmspe:0.10347
# [156]	train-rmse:0.08922	eval-rmse:0.09866	train-rmspe:0.09993	eval-rmspe:0.10323
# [157]	train-rmse:0.08899	eval-rmse:0.09858	train-rmspe:0.09969	eval-rmspe:0.10314
# [158]	train-rmse:0.08879	eval-rmse:0.09849	train-rmspe:0.09948	eval-rmspe:0.10301
# [159]	train-rmse:0.08863	eval-rmse:0.09837	train-rmspe:0.09926	eval-rmspe:0.10284
# [160]	train-rmse:0.08854	eval-rmse:0.09832	train-rmspe:0.09917	eval-rmspe:0.10278
# [161]	train-rmse:0.08828	eval-rmse:0.09810	train-rmspe:0.09893	eval-rmspe:0.10252
# [162]	train-rmse:0.08816	eval-rmse:0.09805	train-rmspe:0.09876	eval-rmspe:0.10248
# [163]	train-rmse:0.08798	eval-rmse:0.09794	train-rmspe:0.09851	eval-rmspe:0.10232
# [164]	train-rmse:0.08779	eval-rmse:0.09790	train-rmspe:0.09828	eval-rmspe:0.10229
# [165]	train-rmse:0.08768	eval-rmse:0.09786	train-rmspe:0.09818	eval-rmspe:0.10225
# [166]	train-rmse:0.08755	eval-rmse:0.09777	train-rmspe:0.09805	eval-rmspe:0.10216
# [167]	train-rmse:0.08751	eval-rmse:0.09777	train-rmspe:0.09801	eval-rmspe:0.10216
# [168]	train-rmse:0.08739	eval-rmse:0.09767	train-rmspe:0.09788	eval-rmspe:0.10204
# [169]	train-rmse:0.08729	eval-rmse:0.09765	train-rmspe:0.09778	eval-rmspe:0.10201
# [170]	train-rmse:0.08720	eval-rmse:0.09764	train-rmspe:0.09632	eval-rmspe:0.10201
# [171]	train-rmse:0.08706	eval-rmse:0.09757	train-rmspe:0.09618	eval-rmspe:0.10193
# [172]	train-rmse:0.08699	eval-rmse:0.09756	train-rmspe:0.09609	eval-rmspe:0.10192
# [173]	train-rmse:0.08685	eval-rmse:0.09740	train-rmspe:0.09594	eval-rmspe:0.10177
# [174]	train-rmse:0.08668	eval-rmse:0.09726	train-rmspe:0.09575	eval-rmspe:0.10164
# [175]	train-rmse:0.08657	eval-rmse:0.09719	train-rmspe:0.09563	eval-rmspe:0.10158
# [176]	train-rmse:0.08647	eval-rmse:0.09727	train-rmspe:0.09550	eval-rmspe:0.10164
# [177]	train-rmse:0.08632	eval-rmse:0.09722	train-rmspe:0.09532	eval-rmspe:0.10158
# [178]	train-rmse:0.08616	eval-rmse:0.09708	train-rmspe:0.09514	eval-rmspe:0.10142
# [179]	train-rmse:0.08613	eval-rmse:0.09704	train-rmspe:0.09510	eval-rmspe:0.10140
# [180]	train-rmse:0.08600	eval-rmse:0.09698	train-rmspe:0.09498	eval-rmspe:0.10130
# [181]	train-rmse:0.08584	eval-rmse:0.09689	train-rmspe:0.09481	eval-rmspe:0.10122
# [182]	train-rmse:0.08573	eval-rmse:0.09685	train-rmspe:0.09470	eval-rmspe:0.10118
# [183]	train-rmse:0.08563	eval-rmse:0.09678	train-rmspe:0.09460	eval-rmspe:0.10111
# [184]	train-rmse:0.08548	eval-rmse:0.09671	train-rmspe:0.09438	eval-rmspe:0.10105
# [185]	train-rmse:0.08539	eval-rmse:0.09664	train-rmspe:0.09429	eval-rmspe:0.10096
# [186]	train-rmse:0.08517	eval-rmse:0.09642	train-rmspe:0.09405	eval-rmspe:0.10074
# [187]	train-rmse:0.08496	eval-rmse:0.09626	train-rmspe:0.09379	eval-rmspe:0.10059
# [188]	train-rmse:0.08482	eval-rmse:0.09618	train-rmspe:0.09364	eval-rmspe:0.10052
# [189]	train-rmse:0.08473	eval-rmse:0.09617	train-rmspe:0.09354	eval-rmspe:0.10050
# [190]	train-rmse:0.08453	eval-rmse:0.09604	train-rmspe:0.09330	eval-rmspe:0.10037
# [191]	train-rmse:0.08445	eval-rmse:0.09601	train-rmspe:0.09322	eval-rmspe:0.10035
# [192]	train-rmse:0.08441	eval-rmse:0.09602	train-rmspe:0.09317	eval-rmspe:0.10035
# [193]	train-rmse:0.08424	eval-rmse:0.09593	train-rmspe:0.09293	eval-rmspe:0.10026
# [194]	train-rmse:0.08413	eval-rmse:0.09587	train-rmspe:0.09279	eval-rmspe:0.10018
# [195]	train-rmse:0.08403	eval-rmse:0.09581	train-rmspe:0.09262	eval-rmspe:0.10010
# [196]	train-rmse:0.08394	eval-rmse:0.09580	train-rmspe:0.09252	eval-rmspe:0.10010
# [197]	train-rmse:0.08391	eval-rmse:0.09579	train-rmspe:0.09249	eval-rmspe:0.10010
# [198]	train-rmse:0.08382	eval-rmse:0.09573	train-rmspe:0.09234	eval-rmspe:0.10002
# [199]	train-rmse:0.08361	eval-rmse:0.09555	train-rmspe:0.09208	eval-rmspe:0.09976
# [200]	train-rmse:0.08348	eval-rmse:0.09548	train-rmspe:0.09197	eval-rmspe:0.09970
# [201]	train-rmse:0.08341	eval-rmse:0.09543	train-rmspe:0.09174	eval-rmspe:0.09965
# [202]	train-rmse:0.08329	eval-rmse:0.09542	train-rmspe:0.09162	eval-rmspe:0.09963
# [203]	train-rmse:0.08321	eval-rmse:0.09539	train-rmspe:0.09153	eval-rmspe:0.09961
# [204]	train-rmse:0.08311	eval-rmse:0.09536	train-rmspe:0.09140	eval-rmspe:0.09958
# [205]	train-rmse:0.08304	eval-rmse:0.09533	train-rmspe:0.09131	eval-rmspe:0.09956
# [206]	train-rmse:0.08285	eval-rmse:0.09518	train-rmspe:0.09104	eval-rmspe:0.09940
# [207]	train-rmse:0.08266	eval-rmse:0.09497	train-rmspe:0.09078	eval-rmspe:0.09924
# [208]	train-rmse:0.08259	eval-rmse:0.09497	train-rmspe:0.09071	eval-rmspe:0.09924
# [209]	train-rmse:0.08248	eval-rmse:0.09490	train-rmspe:0.09059	eval-rmspe:0.09918
# [210]	train-rmse:0.08242	eval-rmse:0.09489	train-rmspe:0.09052	eval-rmspe:0.09919
# [211]	train-rmse:0.08231	eval-rmse:0.09482	train-rmspe:0.09041	eval-rmspe:0.09909
# [212]	train-rmse:0.08223	eval-rmse:0.09480	train-rmspe:0.09029	eval-rmspe:0.09908
# [213]	train-rmse:0.08213	eval-rmse:0.09473	train-rmspe:0.09017	eval-rmspe:0.09900
# [214]	train-rmse:0.08206	eval-rmse:0.09474	train-rmspe:0.09006	eval-rmspe:0.09904
# [215]	train-rmse:0.08202	eval-rmse:0.09471	train-rmspe:0.09004	eval-rmspe:0.09901
# [216]	train-rmse:0.08189	eval-rmse:0.09459	train-rmspe:0.08990	eval-rmspe:0.09884
# [217]	train-rmse:0.08179	eval-rmse:0.09451	train-rmspe:0.08979	eval-rmspe:0.09875
# [218]	train-rmse:0.08167	eval-rmse:0.09449	train-rmspe:0.08966	eval-rmspe:0.09872
# [219]	train-rmse:0.08156	eval-rmse:0.09445	train-rmspe:0.08953	eval-rmspe:0.09869
# [220]	train-rmse:0.08145	eval-rmse:0.09437	train-rmspe:0.08938	eval-rmspe:0.09861
# [221]	train-rmse:0.08136	eval-rmse:0.09431	train-rmspe:0.08929	eval-rmspe:0.09855
# [222]	train-rmse:0.08122	eval-rmse:0.09421	train-rmspe:0.08913	eval-rmspe:0.09846
# [223]	train-rmse:0.08111	eval-rmse:0.09413	train-rmspe:0.08898	eval-rmspe:0.09838
# [224]	train-rmse:0.08097	eval-rmse:0.09408	train-rmspe:0.08878	eval-rmspe:0.09833
# [225]	train-rmse:0.08081	eval-rmse:0.09400	train-rmspe:0.08859	eval-rmspe:0.09823
# [226]	train-rmse:0.08071	eval-rmse:0.09398	train-rmspe:0.08849	eval-rmspe:0.09821
# [227]	train-rmse:0.08057	eval-rmse:0.09391	train-rmspe:0.08832	eval-rmspe:0.09812
# [228]	train-rmse:0.08049	eval-rmse:0.09386	train-rmspe:0.08823	eval-rmspe:0.09805
# [229]	train-rmse:0.08044	eval-rmse:0.09383	train-rmspe:0.08818	eval-rmspe:0.09803
# [230]	train-rmse:0.08032	eval-rmse:0.09380	train-rmspe:0.08804	eval-rmspe:0.09799
# [231]	train-rmse:0.08021	eval-rmse:0.09378	train-rmspe:0.08791	eval-rmspe:0.09799
# [232]	train-rmse:0.08013	eval-rmse:0.09378	train-rmspe:0.08782	eval-rmspe:0.09799
# [233]	train-rmse:0.08002	eval-rmse:0.09372	train-rmspe:0.08761	eval-rmspe:0.09793
# [234]	train-rmse:0.07988	eval-rmse:0.09355	train-rmspe:0.08728	eval-rmspe:0.09763
# [235]	train-rmse:0.07977	eval-rmse:0.09348	train-rmspe:0.08715	eval-rmspe:0.09756
# [236]	train-rmse:0.07967	eval-rmse:0.09347	train-rmspe:0.08707	eval-rmspe:0.09758
# [237]	train-rmse:0.07959	eval-rmse:0.09342	train-rmspe:0.08688	eval-rmspe:0.09752
# [238]	train-rmse:0.07947	eval-rmse:0.09336	train-rmspe:0.08676	eval-rmspe:0.09745
# [239]	train-rmse:0.07941	eval-rmse:0.09332	train-rmspe:0.08669	eval-rmspe:0.09740
# [240]	train-rmse:0.07928	eval-rmse:0.09328	train-rmspe:0.08576	eval-rmspe:0.09738
# [241]	train-rmse:0.07922	eval-rmse:0.09328	train-rmspe:0.08568	eval-rmspe:0.09738
# [242]	train-rmse:0.07912	eval-rmse:0.09324	train-rmspe:0.08555	eval-rmspe:0.09733
# [243]	train-rmse:0.07903	eval-rmse:0.09318	train-rmspe:0.08545	eval-rmspe:0.09725
# [244]	train-rmse:0.07897	eval-rmse:0.09317	train-rmspe:0.08537	eval-rmspe:0.09725
# [245]	train-rmse:0.07890	eval-rmse:0.09313	train-rmspe:0.08528	eval-rmspe:0.09720
# [246]	train-rmse:0.07881	eval-rmse:0.09309	train-rmspe:0.08519	eval-rmspe:0.09716
# [247]	train-rmse:0.07871	eval-rmse:0.09308	train-rmspe:0.08508	eval-rmspe:0.09717
# [248]	train-rmse:0.07861	eval-rmse:0.09306	train-rmspe:0.08496	eval-rmspe:0.09715
# [249]	train-rmse:0.07851	eval-rmse:0.09303	train-rmspe:0.08486	eval-rmspe:0.09713
# [250]	train-rmse:0.07848	eval-rmse:0.09302	train-rmspe:0.08483	eval-rmspe:0.09712
# [251]	train-rmse:0.07838	eval-rmse:0.09296	train-rmspe:0.08471	eval-rmspe:0.09705
# [252]	train-rmse:0.07830	eval-rmse:0.09294	train-rmspe:0.08463	eval-rmspe:0.09702
# [253]	train-rmse:0.07822	eval-rmse:0.09293	train-rmspe:0.08450	eval-rmspe:0.09703
# [254]	train-rmse:0.07815	eval-rmse:0.09292	train-rmspe:0.08443	eval-rmspe:0.09703
# [255]	train-rmse:0.07805	eval-rmse:0.09289	train-rmspe:0.08435	eval-rmspe:0.09700
# [256]	train-rmse:0.07799	eval-rmse:0.09287	train-rmspe:0.08429	eval-rmspe:0.09700
# [257]	train-rmse:0.07791	eval-rmse:0.09285	train-rmspe:0.08421	eval-rmspe:0.09696
# [258]	train-rmse:0.07785	eval-rmse:0.09280	train-rmspe:0.08412	eval-rmspe:0.09691
# [259]	train-rmse:0.07780	eval-rmse:0.09278	train-rmspe:0.08405	eval-rmspe:0.09688
# [260]	train-rmse:0.07774	eval-rmse:0.09273	train-rmspe:0.08400	eval-rmspe:0.09687
# [261]	train-rmse:0.07763	eval-rmse:0.09267	train-rmspe:0.08387	eval-rmspe:0.09680
# [262]	train-rmse:0.07755	eval-rmse:0.09267	train-rmspe:0.08377	eval-rmspe:0.09683
# [263]	train-rmse:0.07746	eval-rmse:0.09266	train-rmspe:0.08365	eval-rmspe:0.09681
# [264]	train-rmse:0.07737	eval-rmse:0.09263	train-rmspe:0.08357	eval-rmspe:0.09677
# [265]	train-rmse:0.07731	eval-rmse:0.09258	train-rmspe:0.08348	eval-rmspe:0.09668
# [266]	train-rmse:0.07727	eval-rmse:0.09258	train-rmspe:0.08343	eval-rmspe:0.09669
# [267]	train-rmse:0.07717	eval-rmse:0.09256	train-rmspe:0.08327	eval-rmspe:0.09665
# [268]	train-rmse:0.07710	eval-rmse:0.09256	train-rmspe:0.08321	eval-rmspe:0.09666
# [269]	train-rmse:0.07703	eval-rmse:0.09254	train-rmspe:0.08311	eval-rmspe:0.09666
# [270]	train-rmse:0.07689	eval-rmse:0.09240	train-rmspe:0.08297	eval-rmspe:0.09652
# [271]	train-rmse:0.07686	eval-rmse:0.09237	train-rmspe:0.08293	eval-rmspe:0.09650
# [272]	train-rmse:0.07678	eval-rmse:0.09242	train-rmspe:0.08285	eval-rmspe:0.09656
# [273]	train-rmse:0.07671	eval-rmse:0.09237	train-rmspe:0.08276	eval-rmspe:0.09651
# [274]	train-rmse:0.07663	eval-rmse:0.09233	train-rmspe:0.08268	eval-rmspe:0.09649
# [275]	train-rmse:0.07659	eval-rmse:0.09234	train-rmspe:0.08264	eval-rmspe:0.09648
# [276]	train-rmse:0.07654	eval-rmse:0.09232	train-rmspe:0.08260	eval-rmspe:0.09647
# [277]	train-rmse:0.07644	eval-rmse:0.09230	train-rmspe:0.08249	eval-rmspe:0.09643
# [278]	train-rmse:0.07638	eval-rmse:0.09229	train-rmspe:0.08232	eval-rmspe:0.09643
# [279]	train-rmse:0.07633	eval-rmse:0.09226	train-rmspe:0.08227	eval-rmspe:0.09636
# [280]	train-rmse:0.07628	eval-rmse:0.09225	train-rmspe:0.08222	eval-rmspe:0.09635
# [281]	train-rmse:0.07619	eval-rmse:0.09221	train-rmspe:0.08191	eval-rmspe:0.09630
# [282]	train-rmse:0.07611	eval-rmse:0.09220	train-rmspe:0.08183	eval-rmspe:0.09629
# [283]	train-rmse:0.07602	eval-rmse:0.09218	train-rmspe:0.08175	eval-rmspe:0.09626
# [284]	train-rmse:0.07597	eval-rmse:0.09218	train-rmspe:0.08165	eval-rmspe:0.09626
# [285]	train-rmse:0.07591	eval-rmse:0.09216	train-rmspe:0.08156	eval-rmspe:0.09625
# [286]	train-rmse:0.07586	eval-rmse:0.09217	train-rmspe:0.08151	eval-rmspe:0.09626
# [287]	train-rmse:0.07583	eval-rmse:0.09215	train-rmspe:0.08147	eval-rmspe:0.09624
# [288]	train-rmse:0.07576	eval-rmse:0.09214	train-rmspe:0.08139	eval-rmspe:0.09623
# [289]	train-rmse:0.07567	eval-rmse:0.09210	train-rmspe:0.08128	eval-rmspe:0.09618
# [290]	train-rmse:0.07559	eval-rmse:0.09208	train-rmspe:0.08119	eval-rmspe:0.09617
# [291]	train-rmse:0.07554	eval-rmse:0.09208	train-rmspe:0.08114	eval-rmspe:0.09617
# [292]	train-rmse:0.07544	eval-rmse:0.09205	train-rmspe:0.08104	eval-rmspe:0.09615
# [293]	train-rmse:0.07538	eval-rmse:0.09204	train-rmspe:0.08098	eval-rmspe:0.09613
# [294]	train-rmse:0.07532	eval-rmse:0.09204	train-rmspe:0.08091	eval-rmspe:0.09612
# [295]	train-rmse:0.07523	eval-rmse:0.09200	train-rmspe:0.08079	eval-rmspe:0.09607
# [296]	train-rmse:0.07516	eval-rmse:0.09200	train-rmspe:0.08071	eval-rmspe:0.09606
# [297]	train-rmse:0.07507	eval-rmse:0.09197	train-rmspe:0.08061	eval-rmspe:0.09604
# [298]	train-rmse:0.07500	eval-rmse:0.09196	train-rmspe:0.08054	eval-rmspe:0.09605
# [299]	train-rmse:0.07495	eval-rmse:0.09195	train-rmspe:0.08049	eval-rmspe:0.09606
# [15:06:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.1.0/src/objective/regression_obj.cu:168: reg:linear is now deprecated in favor of reg:squarederror.

# %%
print("Validating")
yhat = gbm.predict(xgb.DMatrix(X_valid[features]))
error = rmspe(X_valid.Sales.values, np.expm1(yhat))
print('RMSPE: {:.6f}'.format(error))
# Out:
# Validating
# RMSPE: 0.096058

# %%
np.expm1(yhat)
# Out:
# array([ 4044.6326,  5731.406 ,  6150.7925, ...,  6417.1167,  7640.0034,
#        10487.21  ], dtype=float32)

# %%
X_valid.Sales.values
# Out:
# array([4090, 5903, 6062, ..., 6439, 7812, 9799], dtype=int64)

# %%
X_valid[features][52:60]
# Out:
#         Store  CompetitionDistance  Promo  Promo2  SchoolHoliday  StoreType  \
# 702443    931               1480.0      1       1            1.0          1
# 320652    425               1460.0      0       0            0.0          4
# 121320    162               5340.0      0       1            0.0          4
# 378921    502                220.0      1       1            0.0          1
# 231684    309               8740.0      0       1            0.0          4
# 157911    211                350.0      1       0            0.0          1
# 286981    380               2240.0      0       1            0.0          1
# 705528    935              22350.0      0       0            0.0          1
#
#         Assortment  StateHoliday  DayOfWeek  Month  Day  Year  WeekOfYear  \
# 702443           3             0          1      4   29  2014          18
# 320652           3             0          5      1   17  2015           3
# 121320           3             0          2      3   12  2014          11
# 378921           1             0          2     11    5  2014          45
# 231684           1             0          5      5   24  2014          21
# 157911           3             0          4      3    7  2014          10
# 286981           1             0          2      1   16  2013           3
# 705528           3             0          5      1   25  2014           4
#
#         CompetitionOpen  PromoOpen  IsPromoMonth
# 702443             31.0      28.25             1
# 320652          24181.0       0.00             0
# 121320             24.0      47.50             0
# 378921            153.0      62.00             0
# 231684          24173.0      56.00             1
# 157911             88.0       0.00             0
# 286981             -4.0       0.00             0
# 705528             43.0       0.00             0

# %%
X_valid.Sales.values[39:59]
# Out:
# array([12698,  9408,  4185,  7878,  2116,  5218,  5385,  9081,  3938,
#         4783,  3818,  5984,  6266,  4493,  1946,  4641, 11533,  5672,
#        13330, 10302], dtype=int64)

# %%
12 * (data.Year - data.Promo2SinceYear) + \
        (data.WeekOfYear - data.Promo2SinceWeek) / 4.0

# %%
(2012 -2010)+(23-10)/4
# Out:
# 5.25

# %%
12 *(2012 -2010)
# Out:
# 24

# %%
(23-10)/4
# Out:
# 3.25

# %%
24+3.25
# Out:
# 27.25
